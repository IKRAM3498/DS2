# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# data (as pandas dataframes)
X = heart_disease.data.features
y = heart_disease.data.targets

# metadata
print(heart_disease.metadata)

# variable information
print(heart_disease.variables)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# data (as pandas dataframes)
X = heart_disease.data.features
y = heart_disease.data.targets

print('Features (X) Description:')
display(X.describe(include='all'))
# Out:
# Features (X) Description:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Identify numerical and categorical columns from the dataset variables information
numerical_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
categorical_cols = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

print('Generating Histograms for Numerical Features:')
# Generate histograms for numerical features
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 2, i + 1) # Adjust subplot grid based on number of numerical features
    sns.histplot(X[col].dropna(), kde=True, bins=20)
    plt.title(f'Distribution of {col.replace("_", " ").title()}')
    plt.xlabel(col.replace("_", " ").title())
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

print('\nGenerating Bar Charts for Categorical Features:')
# Generate bar charts for categorical features
plt.figure(figsize=(18, 12))
for i, col in enumerate(categorical_cols):
    plt.subplot(3, 3, i + 1) # Adjust subplot grid based on number of categorical features
    X[col].value_counts().sort_index().plot(kind='bar')
    plt.title(f'Value Counts of {col.replace("_", " ").title()}')
    plt.xlabel(col.replace("_", " ").title())
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Generating Histograms for Numerical Features:
# Generating Bar Charts for Categorical Features:

# %% [markdown]
# ## Descriptive Statistics and Visualizations for Target Variable (y)
#
# ### Subtask:
# Calculate and display descriptive statistics for the target variable (y), including value counts. Then, generate a bar chart to visualize the distribution of the target variable, ensuring legends are included.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Descriptive Statistics for Features (X):**
#     *   Descriptive statistics were successfully generated for all features in `X`.
#     *   The `ca` feature had 299 non-null entries out of 303, indicating 4 missing values.
#     *   The `thal` feature had 301 non-null entries out of 303, indicating 2 missing values.
# *   **Visualizations for Numerical Features:** Histograms with Kernel Density Estimates (KDE) were successfully generated for numerical features (`age`, `trestbps`, `chol`, `thalach`, `oldpeak`), providing a visual representation of their distributions.
# *   **Visualizations for Categorical Features:** Bar charts illustrating the value counts were successfully generated for categorical features (`sex`, `cp`, `fbs`, `restecg`, `exang`, `slope`, `ca`, `thal`), showing their frequency distributions.
#
# ### Insights or Next Steps
#
# *   The identified missing values in `ca` and `thal` columns warrant further investigation and handling (e.g., imputation or removal) before any predictive modeling.
# *   The generated visualizations offer a foundational understanding of the data's characteristics and can guide subsequent steps such as feature engineering, outlier detection, or more focused statistical tests.
